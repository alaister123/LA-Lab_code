# %%
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})

# %%
data = pd.read_csv("cooked_all_sep.csv")

# %%
label0 = ' '.join(data[data['Primary code'] == 0]['event_result'])
label1 = ' '.join(data[data['Primary code'] == 1]['event_result'])
label2 = ' '.join(data[data['Primary code'] == 2]['event_result'])
label3 = ' '.join(data[data['Primary code'] == 3]['event_result'])
label4 = ' '.join(data[data['Primary code'] == 4]['event_result'])
label5 = ' '.join(data[data['Primary code'] == 5]['event_result'])
label6 = ' '.join(data[data['Primary code'] == 6]['event_result'])
label7 = ' '.join(data[data['Primary code'] == 7]['event_result'])

# %%
X = data["event_result"]

# %%
Y = data["Primary code"]

# %%
LR = list()

# %%
tfidf = TfidfVectorizer(sublinear_tf=True, stop_words='english',max_features=1000)
tfidf.fit([label0,label1,label2,label3,label4,label5,label6,label7])
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.2)
clf = LogisticRegression(tol=1e-5,C=1,max_iter=150)
clf.fit(tfidf.transform(X_train).toarray(),Y_train)
LR.append(clf.score(tfidf.transform(X_test).toarray(), Y_test))

# %%
tfidf = TfidfVectorizer(sublinear_tf=True, stop_words='english',max_features=5000)
tfidf.fit([label0,label1,label2,label3,label4,label5,label6,label7])
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.2)
clf = LogisticRegression(tol=1e-5,C=1,max_iter=150)
clf.fit(tfidf.transform(X_train).toarray(),Y_train)
LR.append(clf.score(tfidf.transform(X_test).toarray(), Y_test))

# %%
tfidf = TfidfVectorizer(sublinear_tf=True, stop_words='english',max_features=10000)
tfidf.fit([label0,label1,label2,label3,label4,label5,label6,label7])
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.2)
clf = LogisticRegression(tol=1e-5,C=1,max_iter=150)
clf.fit(tfidf.transform(X_train).toarray(),Y_train)
LR.append(clf.score(tfidf.transform(X_test).toarray(), Y_test))

# %%
tfidf = TfidfVectorizer(sublinear_tf=True, stop_words='english')
tfidf.fit([label0,label1,label2,label3,label4,label5,label6,label7])
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.2)
clf = LogisticRegression(tol=1e-5,C=1,max_iter=150)
clf.fit(tfidf.transform(X_train).toarray(),Y_train)
LR.append(clf.score(tfidf.transform(X_test).toarray(), Y_test))

# %%
LR
# Out:
# [0.5773279352226721,
#  0.5813765182186235,
#  0.6024291497975709,
#  0.5935222672064777]

# %%
SVM = list()

# %%
tfidf = TfidfVectorizer(sublinear_tf=True, stop_words='english',max_features=1000)
tfidf.fit([label0,label1,label2,label3,label4,label5,label6,label7])
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.2)
clf = LinearSVC(tol=1e-5,C=0.1,max_iter=2000)
clf.fit(tfidf.transform(X_train).toarray(),Y_train)
SVM.append(clf.score(tfidf.transform(X_test).toarray(), Y_test))

# %%
tfidf = TfidfVectorizer(sublinear_tf=True, stop_words='english',max_features=5000)
tfidf.fit([label0,label1,label2,label3,label4,label5,label6,label7])
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.2)
clf = LinearSVC(tol=1e-5,C=0.1,max_iter=2000)
clf.fit(tfidf.transform(X_train).toarray(),Y_train)
SVM.append(clf.score(tfidf.transform(X_test).toarray(), Y_test))

# %%
tfidf = TfidfVectorizer(sublinear_tf=True, stop_words='english',max_features=10000)
tfidf.fit([label0,label1,label2,label3,label4,label5,label6,label7])
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.2)
clf = LinearSVC(tol=1e-5,C=0.1,max_iter=2000)
clf.fit(tfidf.transform(X_train).toarray(),Y_train)
SVM.append(clf.score(tfidf.transform(X_test).toarray(), Y_test))

# %%
tfidf = TfidfVectorizer(sublinear_tf=True, stop_words='english')
tfidf.fit([label0,label1,label2,label3,label4,label5,label6,label7])
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.2)
clf = LinearSVC(tol=1e-5,C=0.1,max_iter=2000)
clf.fit(tfidf.transform(X_train).toarray(),Y_train)
SVM.append(clf.score(tfidf.transform(X_test).toarray(), Y_test))

# %%
SVM
# Out:
# [0.5838056680161944,
#  0.5975708502024292,
#  0.5991902834008097,
#  0.5757085020242915]

# %%
NB = list()

# %%
tfidf = TfidfVectorizer(sublinear_tf=True, stop_words='english',max_features=1000)
tfidf.fit([label0,label1,label2,label3,label4,label5,label6,label7])
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.2)
clf = MultinomialNB(alpha=1e-10)
clf.fit(tfidf.transform(X_train).toarray(),Y_train)
NB.append(clf.score(tfidf.transform(X_test).toarray(), Y_test))

# %%
tfidf = TfidfVectorizer(sublinear_tf=True, stop_words='english',max_features=5000)
tfidf.fit([label0,label1,label2,label3,label4,label5,label6,label7])
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.2)
clf = MultinomialNB(alpha=1e-10)
clf.fit(tfidf.transform(X_train).toarray(),Y_train)
NB.append(clf.score(tfidf.transform(X_test).toarray(), Y_test))

# %%
tfidf = TfidfVectorizer(sublinear_tf=True, stop_words='english',max_features=10000)
tfidf.fit([label0,label1,label2,label3,label4,label5,label6,label7])
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.2)
clf = MultinomialNB(alpha=1e-10)
clf.fit(tfidf.transform(X_train).toarray(),Y_train)
NB.append(clf.score(tfidf.transform(X_test).toarray(), Y_test))

# %%
tfidf = TfidfVectorizer(sublinear_tf=True, stop_words='english')
tfidf.fit([label0,label1,label2,label3,label4,label5,label6,label7])
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.2)
clf = MultinomialNB(alpha=1e-10)
clf.fit(tfidf.transform(X_train).toarray(),Y_train)
NB.append(clf.score(tfidf.transform(X_test).toarray(), Y_test))

# %%
NB
# Out:
# [0.5635627530364372,
#  0.5554655870445344,
#  0.5360323886639676,
#  0.5425101214574899]

# %%
RF = list()

# %%
tfidf = TfidfVectorizer(sublinear_tf=True, stop_words='english',max_features=1000)
tfidf.fit([label0,label1,label2,label3,label4,label5,label6,label7])
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.2)
clf = RandomForestClassifier(max_depth=70,min_samples_split=5)
clf.fit(tfidf.transform(X_train).toarray(),Y_train)
RF.append(clf.score(tfidf.transform(X_test).toarray(), Y_test))

# %%
tfidf = TfidfVectorizer(sublinear_tf=True, stop_words='english',max_features=5000)
tfidf.fit([label0,label1,label2,label3,label4,label5,label6,label7])
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.2)
clf = RandomForestClassifier(max_depth=70,min_samples_split=5)
clf.fit(tfidf.transform(X_train).toarray(),Y_train)
RF.append(clf.score(tfidf.transform(X_test).toarray(), Y_test))

# %%
tfidf = TfidfVectorizer(sublinear_tf=True, stop_words='english',max_features=10000)
tfidf.fit([label0,label1,label2,label3,label4,label5,label6,label7])
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.2)
clf = RandomForestClassifier(max_depth=70,min_samples_split=5)
clf.fit(tfidf.transform(X_train).toarray(),Y_train)
RF.append(clf.score(tfidf.transform(X_test).toarray(), Y_test))

# %%
tfidf = TfidfVectorizer(sublinear_tf=True, stop_words='english')
tfidf.fit([label0,label1,label2,label3,label4,label5,label6,label7])
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.2)
clf = RandomForestClassifier(max_depth=70,min_samples_split=5)
clf.fit(tfidf.transform(X_train).toarray(),Y_train)
RF.append(clf.score(tfidf.transform(X_test).toarray(), Y_test))

# %%
RF
# Out:
# [0.5732793522267207,
#  0.5522267206477732,
#  0.5489878542510122,
#  0.5246963562753036]

# %%
import matplotlib.pyplot as plt

# %%
x = [LR,SVM,NB,RF]

# %%
x = [LR,SVM,NB,RF]
plt.rcParams['font.size'] = '16'
plt.figure(figsize=(20,15))

for i,j in zip(x,["LR",'SVM','NB','RF']):
    plt.plot([1000, 5000, 10000, "unlimited"], i, label = j,linewidth=10)

plt.xticks(fontsize= 50)
plt.yticks(fontsize= 50)
plt.legend(loc=2, prop={'size': 30})
plt.savefig("max_feature_graph.png")
plt.show()

# %%
# Out:
# [0.5635627530364372,
#  0.5554655870445344,
#  0.5360323886639676,
#  0.5425101214574899]
